# %%
# PyTorch
import torch
from torch import nn

# NumPy
import numpy as np

# Plots
import matplotlib.pyplot as plt

# Math
import math

# Time
import time

# Checks to see if gpu is available. If it is, use it else use cpu
if torch.cuda.is_available():
    device = torch.device('cuda')
    print(f'Using {device}: {torch.cuda.get_device_name()}')
else:
    device = torch.device('cpu')
    print('No GPU found, using cpu')
# Out:
# Using cuda: NVIDIA GeForce RTX 3050 Laptop GPU

# %%
# Initializes NN-based solver hyperparameters
def initParams(D: int, M: int, H: list, L: float, 
               B: int, lr: float, weight_decay: int, I: int,
               alpha: float, beta: float, sigma: float):
    params = dict()
    # Direct solver hyperparameters
    params['D'] = D # Dimension of the coordinate space
    params['M'] = M # Dimension of the final space (number 
      # of bottom states we want to find)
    params['H'] = H # Sizes of NN hidden layers
    params['L'] = L # Box size
    # Indirect solver hyperparameters
    params['B'] = B # Batch size
    params['lr'] = lr # Learning rate
    params['weight_decay'] = weight_decay # Weight decay 
      # (Adam optimizer parameter)
    params['I'] = I # Amount of training iterations
    params['alpha'] = alpha
    params['beta'] = beta
    params['sigma'] = sigma
    # Paths to save and load model
    stringH = ""
    for i in range(len(H)):
        stringH += f"{H[i]},"
    params['nnbmssPath'] = f"../models/D{D}_M{M}_H{stringH}_L{L}.pt"
    # Paths to save figures
    params['nnbmssPathFigure'] = f"../figs/D{D}_M{M}_H{stringH}_L{L}.pt"
    return params

# %%
f0 = lambda x: torch.tanh(x)
f1 = lambda x: 1/torch.cosh(x)**2
f2 = lambda x: -2*torch.sinh(x)/torch.cosh(x)**3

class Perceptron(nn.Module):
  def __init__(self, params):
    assert len(params['H']) > 0, "List of hidden layers' widths is empty"
    super(Perceptron, self).__init__()
    self.D = params['D'] # Dimension of the initial space
    self.M = params['M'] # Dimension of the final space
    self.N = len(params['H']) # Number of the hidden layers
    self.L = params['L'] # Box size
    self.stack = nn.Sequential() # Structure of the perceptron
    for n in range(self.N + 1):
      if (n == 0):
        self.stack.append(nn.Linear(self.D, params['H'][0]))
      elif (n == self.N):
        self.stack.append(nn.Linear(params['H'][-1], self.M))
      else:
        self.stack.append(nn.Linear(params['H'][n-1], params['H'][n]))
      self.stack.append(nn.Tanh())
    self.stack.to(device)
  
  # Normal distribution
  def weight(self, x: torch.Tensor, mean: float, std: float):
    assert x.shape[1] == self.D, "Wrong shape 1 of the tensor x"
    assert x.shape[0] > 0, "Wrong shape 0 of the tensor x"
    return 1 / (std * math.sqrt(2 * math.pi))**self.D \
      * torch.exp(-0.5 * torch.sum((x - mean)**2, axis=1) / std**2)
  
  def stack_gradient(self, x: torch.Tensor):
    assert x.shape[1] == self.D, "Wrong shape 1 of the tensor x"
    assert x.shape[0] > 0, "Wrong shape 0 of the tensor x"
    result = torch.zeros((x.shape[0], self.D, self.M)).to(device)
    # Computation of the y
    y = [None] * (self.N + 1)
    y[0] = x
    for i in range(self.N):
      # y(i+1)
      y[i+1] = self.stack[i*2+1](self.stack[i*2](y[i]))
    # Computation of the result
    for d in range(self.D):
      # dy(1)dx
      dydx = f1(self.stack[0](y[0])) * self.stack[0].weight[:,d]
      for i in range(1, self.N + 1):
        # dy(i)dx
        dydx =  f1(self.stack[i*2](y[i])) \
          * torch.matmul(dydx, self.stack[i*2].weight.t())
      # keeping result
      result[:,d,:] = dydx
    return result
  
  def stack_laplacian(self, x: torch.Tensor):
    assert x.shape[1] == self.D, "Wrong shape 1 of the tensor x"
    assert x.shape[0] > 0, "Wrong shape 0 of the tensor x"
    preresult = torch.zeros((x.shape[0], self.D, self.M)).to(device)
    # Computation of the y
    y = [None] * (self.N + 1)
    y[0] = x
    for i in range(self.N):
      # y(i+1)
      y[i+1] = self.stack[i*2+1](self.stack[i*2](y[i]))
    # Computation of the result
    for d in range(self.D):
      # dy(1)dx
      dydx = f1(self.stack[0](y[0])) * self.stack[0].weight[:,d]
      # d2y(2)dx2
      d2ydx2 = f2(self.stack[0](y[0])) * self.stack[0].weight[:,d]**2
      for i in range(1, self.N + 1):
        # d2y(i)dx2
        d2ydx2 = f2(self.stack[i*2](y[i])) \
          * torch.matmul(dydx, self.stack[i*2].weight.t())**2 \
          + f1(self.stack[i*2](y[i])) \
          * torch.matmul(d2ydx2, self.stack[i*2].weight.t())
        # dy(i)dx
        dydx =  f1(self.stack[i*2](y[i])) \
          * torch.matmul(dydx, self.stack[i*2].weight.t())
      # keeping preresult
      preresult[:,d,:] = d2ydx2
    return torch.sum(preresult, axis=1) 
  
  def amplitude(self, x: torch.Tensor):
    assert x.shape[1] == self.D, "Wrong shape of the tensor x"
    assert x.shape[0] > 0, "Wrong shape of the tensor x"
    # mask = (torch.sum(abs(x)<=self.L, axis=1) == self.D).to(device)
    result = torch.ones((x.shape[0], self.M)).to(device)
    # result = torch.mul(result, 1 / torch.sum(self.stack(x)**2, axis=0))
    result = torch.mul(result.t(), 
                       torch.exp(- torch.sum(x**4, axis=1) / self.L**4)).t()
    # result = torch.mul(result.t(),
    #                    (1 - torch.sum(x**2, axis=1) / self.L**2) * mask).t()
    assert result.shape[1] == self.M, "Wrong shape 1 of the result"
    assert result.shape[0] == x.shape[0], "Wrong shape 0 of the result"
    return result
  
  def amplitude_gradient(self, x: torch.Tensor):
    assert x.shape[1] == self.D, "Wrong shape of the tensor x"
    assert x.shape[0] > 0, "Wrong shape of the tensor x"
    # mask = (torch.sum(abs(x)<=self.L, axis=1) == self.D).to(device)
    result = torch.ones((x.shape[0], self.D, self.M)).to(device)
    # s = self.stack(x)
    # sg = self.stack_gradient(x)
    for d in range(self.D):
      # first term
      a = torch.ones((x.shape[0], self.M)).to(device)
      a = torch.mul(a.t(), 
                    torch.exp(- torch.sum(x**4, axis=1) / self.L**4) \
                    * (- 4 * x[:,d]**3 / self.L**4)).t()
      # a = torch.mul(a.t(), -2 * x[:,d] / self.L**2 * mask).t()
      # keeping result
      result[:,d,:] = a #+ b
    return result

  def amplitude_laplacian(self, x: torch.Tensor):
    assert x.shape[1] == self.D, "Wrong shape of the tensor x"
    assert x.shape[0] > 0, "Wrong shape of the tensor x"
    # mask = (torch.sum(abs(x)<=self.L, axis=1) == self.D).to(device)
    a = torch.ones((x.shape[0], self.M)).to(device)
    result = torch.mul(a.t(), 
                       torch.exp(- torch.sum(x**4, axis=1) / self.L**4) \
                       * (torch.sum((-4*x**3/self.L**4)**2, axis=1) \
                          - 12 * torch.sum(x**2/self.L**4, axis=1))).t()
    # result = torch.mul(a.t(), -2 * self.D / self.L**2 * mask).t()
    return result
    
  def forward(self, x: torch.Tensor):
    assert x.shape[1] == self.D, "Wrong shape 1 of the tensor x"
    assert x.shape[0] > 0, "Wrong shape 0 of the tensor x"
    result = self.stack(x).to(device) * self.amplitude(x).to(device) # Multiply by amplitude
    assert result.shape[1] == self.M, "Wrong shape 1 of the result"
    assert result.shape[0] == x.shape[0], "Wrong shape 0 of the result"
    return result
  
  def gradient(self, x: torch.Tensor):
    assert x.shape[1] == self.D, "Wrong shape of the tensor x"
    assert x.shape[0] > 0, "Wrong shape of the tensor x"
    result = torch.zeros((x.shape[0], self.D, self.M)).to(device)
    a = self.amplitude(x)
    sg = self.stack_gradient(x)
    s = self.stack(x)
    ag = self.amplitude_gradient(x)
    for d in range(self.D):
      result[:,d,:] = sg[:,d,:] * a + s * ag[:,d,:]
    return result

  def laplacian(self, x: torch.Tensor):
    assert x.shape[1] == self.D, "Wrong shape of the tensor x"
    assert x.shape[0] > 0, "Wrong shape of the tensor x"
    result = self.stack_laplacian(x) * self.amplitude(x) \
      + self.stack(x) * self.amplitude_laplacian(x) \
      + 2 * torch.sum(self.stack_gradient(x) * self.amplitude_gradient(x), 
                      axis=1)
    return result
  
  def wavefunction_norm2(self, x: torch.Tensor, mean: float, std: float):
    assert x.shape[1] == self.D, "Wrong shape 1 of the tensor x"
    assert x.shape[0] > 0, "Wrong shape 0 of the tensor x"
    result = torch.zeros(self.M).to(device)
    f = self.forward(x)
    w = self.weight(x, mean, std)
    for m in range(self.M):
      result[m] = torch.mean(abs(f[:,m])**2 / w)
    return result
  
  def mean_hamiltonian(self, x: torch.Tensor, mean: float, std: float):
    assert x.shape[1] == self.D, "Wrong shape 1 of the tensor x"
    assert x.shape[0] > 0, "Wrong shape 0 of the tensor x"
    result = torch.zeros(self.M).to(device)
    f = self.forward(x)
    l = self.laplacian(x)
    w = self.weight(x, mean, std)
    v = 0.5 * torch.sum(x**2, axis=1)
    for m in range(self.M):
      result[m] = torch.mean(f[:,m] * (-0.5 * l[:,m] + v * f[:,m]) / w)
    return result
  
  def energies(self, x: torch.Tensor, mean: float, std: float):
    assert x.shape[1] == self.D, "Wrong shape 1 of the tensor x"
    assert x.shape[0] > 0, "Wrong shape 0 of the tensor x"
    return self.mean_hamiltonian(x, mean, std) \
      / self.wavefunction_norm2(x, mean, std)
  
  def load_model(self, params):
    self.load_state_dict(params['nnbmssPath'])
  
  def save_model(self, params):
    torch.save(self.state_dict(), params['nnbmssPath'])

  def train_step(self, optimizer, loss_function, B: int, mean: float,
                 std: float, loss_weights: dict, sigma: float):
    # Normal distributed x
    x = torch.normal(mean=mean, std=std, size=(B, self.D)).to(device)
    e = self.energies(x, mean, std)
    f = self.forward(x)
    w = self.weight(x, mean, std)
    # Residual
    residual = -0.5 * self.laplacian(x) \
      + 0.5 * torch.mul(f.t(), torch.sum(x**2, axis=1)).t() \
      - torch.mul(f, e)
    # Orthonormalization
    norm = torch.sqrt(self.wavefunction_norm2(x, mean, std))
    a = torch.sum((norm - torch.tensor(1).to(device))**2)
    b = torch.zeros(self.M, self.M).to(device)#.to(device)
    for m1 in range(1, self.M):
      for m2 in range(0, m1):
        b[m1,m2] = torch.mean(f[:,m1] * f[:,m2] / w)**2
    # Loss
    tau = 1.
    loss = loss_function(
        loss_weights['r'] * torch.mean(torch.mean((residual)**2, axis=0))
        + + loss_weights['e'] * torch.sum(e)
        + loss_weights['a'] * a 
        + loss_weights['b'] * torch.sum(b),
        torch.tensor(0.0).to(device))
    # Backpropagation
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    # scheduler.step()
    self.L = self.L * sigma
    return loss.item(), np.mean(residual.cpu().detach().numpy(), axis=0), \
      a.cpu().detach().numpy(), \
      torch.sum(b).cpu().detach().numpy(), e.cpu().detach().numpy()
  
  def train_loop(self, params):
    start_time = time.time()
    e_list = [None] * params['I']
    l_list = [None] * params['I']
    r_list = [None] * params['I']
    a_list = [None] * params['I']
    b_list = [None] * params['I']
    loss_weights = dict()
    loss_weights['r'] = 1
    loss_weights['a'] = 10
    loss_weights['b'] = 100
    params['loss_weights'] = loss_weights
    x = torch.normal(mean=0, std=self.L/math.sqrt(2), size=(params['B'], self.D)).to(device)
    loss_weights['e'] = torch.sum(self.energies(x, mean=0., std=self.L/math.sqrt(2))).cpu().detach()
    optimizer = torch.optim.AdamW(params=list(self.parameters()), 
                                 lr=params['lr'], 
                                 weight_decay=params['weight_decay'])
    # Main loop
    print('i,\t Loss,\t Sorted energies,\t Time [s]')
    for i in range(params['I']):
        l_list[i], r_list[i], a_list[i], b_list[i], e_list[i] = self.train_step(optimizer, 
                                                                              nn.MSELoss(),
                                                                              B=params['B'],
                                                                              mean=0.,
                                                                              std=self.L/math.sqrt(2),
                                                                              loss_weights=loss_weights,
                                                                              sigma=params['sigma'])
        if i % 500 == 0:
            print(f"{i:3d}\t {l_list[i]:.4E}\t {np.sort(e_list[i])}\t {time.time()-start_time}")
            # Empty cache
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
            # Save model parameters
            self.save_model(params)
        
        if i % 100 == 0:
            # if (loss_weights['r'] == 500) and (loss_weights['a'] == 10) and (loss_weights['b'] == 10):
            #     break
            
            x = torch.normal(mean=0, std=self.L/math.sqrt(2), size=(params['B'], self.D)).to(device)
            e = self.energies(x, mean=0, std=self.L/math.sqrt(2))
            f = self.forward(x)
            w = self.weight(x, mean=0, std=self.L/math.sqrt(2))
            # Residual
            residual = -0.5 * self.laplacian(x) \
              + 0.5 * torch.mul(f.t(), torch.sum(x**2, axis=1)).t() \
              - torch.mul(f, e)
            # Orthonormalization
            norm = torch.sqrt(self.wavefunction_norm2(x, mean=0, std=self.L/math.sqrt(2)))
            a = torch.sum((norm - torch.tensor(1).to(device))**2)
            b = torch.zeros(self.M, self.M).to(device)#.to(device)
            for m1 in range(1, self.M):
                for m2 in range(0, m1):
                    b[m1,m2] = torch.mean(f[:,m1] * f[:,m2] / w)**2
        
            loss_weights['r'] = min(1/ torch.mean(torch.mean((residual)**2, axis=0)).cpu().detach(), 500)
            loss_weights['a'] = min(1/a.cpu().detach(),10)
            loss_weights['b'] = min(1/torch.sum(b).cpu().detach(),10)
            loss_weights['e'] = 1/torch.sum(e).cpu().detach()
            
            print("loss_weights:")
            print(loss_weights)
            
            params['loss_weights'] = loss_weights
            # Empty cache
            if torch.cuda.is_available():
                torch.cuda.empty_cache()
        
    # Empty cache
    if torch.cuda.is_available():
        torch.cuda.empty_cache()           
    return e_list, l_list, r_list, a_list, b_list, time.time()-start_time

# %%
torch.cuda.empty_cache()

# %%
params = initParams(D=3, M=5, H=[50,50,50], L=3, 
                    B=int(2**13), lr=1e-3, weight_decay=1e-3, I=30000,
                    alpha=10, beta=100, sigma=1.5**(1/30000))
perceptron = Perceptron(params).to(device)

# %%
e_list, l_list, r_list, a_list, b_list, t = perceptron.train_loop(params)
# Out:
# i,	 Loss,	 Sorted energies,	 Time [s]
#   0	 4.1769E+06	 [3.6510756 3.6646705 3.9264765 3.9857213 4.0351305]	 0.6501519680023193
# loss_weights:
# {'r': tensor(56.3906), 'a': tensor(1.1378), 'b': tensor(0.1437), 'e': tensor(0.0506)}
# loss_weights:
# {'r': tensor(76.4822), 'a': tensor(1.1412), 'b': tensor(0.3531), 'e': tensor(0.0484)}
# loss_weights:
# {'r': tensor(75.8382), 'a': tensor(1.2129), 'b': tensor(0.3653), 'e': tensor(0.0481)}
# loss_weights:
# {'r': tensor(76.2325), 'a': tensor(1.2549), 'b': tensor(0.3694), 'e': tensor(0.0477)}
# loss_weights:
# {'r': tensor(76.2259), 'a': tensor(1.3118), 'b': tensor(0.4010), 'e': tensor(0.0479)}
# 500	 1.5180E+01	 [3.7348173 3.9463208 4.3736424 4.419471  4.557142 ]	 36.702977657318115
# loss_weights:
# {'r': tensor(78.5823), 'a': tensor(1.5256), 'b': tensor(0.4466), 'e': tensor(0.0480)}
# loss_weights:
# {'r': tensor(78.9704), 'a': tensor(1.6318), 'b': tensor(0.4641), 'e': tensor(0.0480)}
# loss_weights:
# {'r': tensor(80.1657), 'a': tensor(1.8018), 'b': tensor(0.4844), 'e': tensor(0.0478)}
# loss_weights:
# {'r': tensor(82.0048), 'a': tensor(2.0059), 'b': tensor(0.5545), 'e': tensor(0.0481)}
# loss_weights:
# {'r': tensor(83.8825), 'a': tensor(2.2771), 'b': tensor(0.6244), 'e': tensor(0.0480)}
# 1000	 1.4668E+01	 [3.763984  3.785653  4.3672395 4.439241  4.5171432]	 73.60080313682556
# loss_weights:
# {'r': tensor(84.3719), 'a': tensor(2.4957), 'b': tensor(0.6833), 'e': tensor(0.0484)}
# loss_weights:
# {'r': tensor(85.3992), 'a': tensor(2.9044), 'b': tensor(0.7456), 'e': tensor(0.0480)}
# loss_weights:
# {'r': tensor(88.5287), 'a': tensor(3.4127), 'b': tensor(0.8775), 'e': tensor(0.0484)}
# loss_weights:
# {'r': tensor(93.1319), 'a': tensor(4.1083), 'b': tensor(0.9657), 'e': tensor(0.0483)}
# loss_weights:
# {'r': tensor(93.4025), 'a': tensor(5.0151), 'b': tensor(1.0966), 'e': tensor(0.0481)}
# 1500	 1.3293E+01	 [3.4742458 3.7038114 4.3394036 4.5404625 4.6442943]	 109.92824363708496
# loss_weights:
# {'r': tensor(94.5792), 'a': tensor(6.3271), 'b': tensor(1.1505), 'e': tensor(0.0482)}
# loss_weights:
# {'r': tensor(99.1605), 'a': tensor(9.3750), 'b': tensor(1.2319), 'e': tensor(0.0490)}
# loss_weights:
# {'r': tensor(98.8884), 'a': 10, 'b': tensor(1.1562), 'e': tensor(0.0486)}
# loss_weights:
# {'r': tensor(95.0169), 'a': 10, 'b': tensor(1.1472), 'e': tensor(0.0487)}
# loss_weights:
# {'r': tensor(97.8683), 'a': 10, 'b': tensor(1.1970), 'e': tensor(0.0484)}
# 2000	 1.0820E+01	 [3.3017168 3.7923164 4.3792987 4.528946  4.708943 ]	 146.27717804908752
# loss_weights:
# {'r': tensor(95.6147), 'a': 10, 'b': tensor(1.2709), 'e': tensor(0.0479)}
# loss_weights:
# {'r': tensor(97.6693), 'a': 10, 'b': tensor(1.3680), 'e': tensor(0.0483)}
# loss_weights:
# {'r': tensor(97.0952), 'a': 10, 'b': tensor(1.4964), 'e': tensor(0.0476)}
# loss_weights:
# {'r': tensor(98.3772), 'a': 10, 'b': tensor(1.6816), 'e': tensor(0.0477)}
# loss_weights:
# {'r': tensor(93.1906), 'a': 10, 'b': tensor(1.8625), 'e': tensor(0.0473)}
# 2500	 9.8033E+00	 [3.47675   3.9670289 4.4355397 4.5583405 4.776432 ]	 182.8981728553772
# loss_weights:
# {'r': tensor(93.6046), 'a': 10, 'b': tensor(2.0543), 'e': tensor(0.0467)}
# loss_weights:
# {'r': tensor(93.2860), 'a': 10, 'b': tensor(2.2326), 'e': tensor(0.0468)}
# loss_weights:
# {'r': tensor(93.7422), 'a': 10, 'b': tensor(2.3371), 'e': tensor(0.0461)}
# loss_weights:
# {'r': tensor(96.9531), 'a': 10, 'b': tensor(2.3889), 'e': tensor(0.0464)}
# loss_weights:
# {'r': tensor(94.4792), 'a': 10, 'b': tensor(2.4988), 'e': tensor(0.0454)}
# 3000	 1.0516E+01	 [3.7198737 4.2043085 4.538373  4.707351  4.9067674]	 219.5113127231598
# loss_weights:
# {'r': tensor(92.3722), 'a': 10, 'b': tensor(2.3688), 'e': tensor(0.0452)}
# loss_weights:
# {'r': tensor(95.3367), 'a': 10, 'b': tensor(2.4391), 'e': tensor(0.0457)}
# loss_weights:
# {'r': tensor(90.6783), 'a': 10, 'b': tensor(2.4477), 'e': tensor(0.0451)}
# loss_weights:
# {'r': tensor(94.9758), 'a': 10, 'b': tensor(2.5753), 'e': tensor(0.0455)}
# loss_weights:
# {'r': tensor(92.0387), 'a': 10, 'b': tensor(2.5200), 'e': tensor(0.0451)}
# 3500	 1.0131E+01	 [3.6524878 4.1985497 4.4983845 4.720335  4.9092746]	 255.71553564071655
# loss_weights:
# {'r': tensor(93.4695), 'a': 10, 'b': tensor(2.4298), 'e': tensor(0.0454)}
# loss_weights:
# {'r': tensor(93.9705), 'a': 10, 'b': tensor(2.5213), 'e': tensor(0.0453)}
# loss_weights:
# {'r': tensor(94.0934), 'a': 10, 'b': tensor(2.6149), 'e': tensor(0.0450)}
# loss_weights:
# {'r': tensor(96.1160), 'a': 10, 'b': tensor(2.5621), 'e': tensor(0.0454)}
# loss_weights:
# {'r': tensor(94.0505), 'a': 10, 'b': tensor(2.5922), 'e': tensor(0.0449)}
# 4000	 1.0347E+01	 [3.6499593 4.2974334 4.5983996 4.848737  5.0178432]	 292.1097242832184
# loss_weights:
# {'r': tensor(95.9900), 'a': 10, 'b': tensor(2.7049), 'e': tensor(0.0448)}
# loss_weights:
# {'r': tensor(95.0819), 'a': 10, 'b': tensor(2.6767), 'e': tensor(0.0445)}
# loss_weights:
# {'r': tensor(94.7090), 'a': 10, 'b': tensor(2.7404), 'e': tensor(0.0440)}
# loss_weights:
# {'r': tensor(94.7989), 'a': 10, 'b': tensor(2.9154), 'e': tensor(0.0441)}
# loss_weights:
# {'r': tensor(95.8807), 'a': 10, 'b': tensor(2.9372), 'e': tensor(0.0439)}
# 4500	 1.0935E+01	 [3.573696  4.424271  4.6990943 4.913795  5.0359397]	 328.9931585788727
# loss_weights:
# {'r': tensor(95.4408), 'a': 10, 'b': tensor(2.9794), 'e': tensor(0.0440)}
# loss_weights:
# {'r': tensor(94.4776), 'a': 10, 'b': tensor(2.9105), 'e': tensor(0.0436)}
# loss_weights:
# {'r': tensor(95.9379), 'a': 10, 'b': tensor(2.8821), 'e': tensor(0.0439)}
# loss_weights:
# {'r': tensor(95.5026), 'a': 10, 'b': tensor(3.0080), 'e': tensor(0.0439)}
# loss_weights:
# {'r': tensor(93.8273), 'a': 10, 'b': tensor(3.1391), 'e': tensor(0.0437)}
# 5000	 1.0621E+01	 [3.5264802 4.494261  4.698815  5.0285435 5.1799216]	 365.22803115844727
# loss_weights:
# {'r': tensor(96.9356), 'a': 10, 'b': tensor(3.2135), 'e': tensor(0.0437)}
# loss_weights:
# {'r': tensor(96.8004), 'a': 10, 'b': tensor(3.1426), 'e': tensor(0.0437)}
# loss_weights:
# {'r': tensor(97.0204), 'a': 10, 'b': tensor(3.3760), 'e': tensor(0.0434)}
# loss_weights:
# {'r': tensor(98.2290), 'a': 10, 'b': tensor(3.4177), 'e': tensor(0.0433)}
# loss_weights:
# {'r': tensor(98.6724), 'a': 10, 'b': tensor(3.5226), 'e': tensor(0.0432)}
# 5500	 1.0456E+01	 [3.4654944 4.626345  4.7549696 5.110113  5.1688156]	 401.4951159954071
# loss_weights:
# {'r': tensor(97.2956), 'a': 10, 'b': tensor(3.8999), 'e': tensor(0.0429)}
# loss_weights:
# {'r': tensor(96.9834), 'a': 10, 'b': tensor(3.9579), 'e': tensor(0.0429)}
# loss_weights:
# {'r': tensor(99.5225), 'a': 10, 'b': tensor(4.3259), 'e': tensor(0.0427)}
# loss_weights:
# {'r': tensor(99.2039), 'a': 10, 'b': tensor(4.7866), 'e': tensor(0.0428)}
# loss_weights:
# {'r': tensor(99.6090), 'a': 10, 'b': tensor(5.5686), 'e': tensor(0.0423)}
# 6000	 1.0441E+01	 [3.3756242 4.861393  4.904986  5.3091893 5.3475833]	 438.19378089904785
# loss_weights:
# {'r': tensor(99.3481), 'a': 10, 'b': tensor(7.1653), 'e': tensor(0.0423)}
# loss_weights:
# {'r': tensor(101.1818), 'a': 10, 'b': tensor(9.9209), 'e': tensor(0.0414)}
# loss_weights:
# {'r': tensor(102.1138), 'a': 10, 'b': 10, 'e': tensor(0.0417)}
# loss_weights:
# {'r': tensor(103.4006), 'a': 10, 'b': 10, 'e': tensor(0.0416)}
# loss_weights:
# {'r': tensor(99.0640), 'a': 10, 'b': 10, 'e': tensor(0.0413)}
# 6500	 5.2329E+00	 [3.3119097 4.939261  5.0568314 5.2909775 5.451103 ]	 474.57782220840454
# loss_weights:
# {'r': tensor(96.9848), 'a': 10, 'b': 10, 'e': tensor(0.0412)}
# loss_weights:
# {'r': tensor(96.1264), 'a': 10, 'b': 10, 'e': tensor(0.0413)}
# loss_weights:
# {'r': tensor(93.3655), 'a': 10, 'b': 10, 'e': tensor(0.0411)}
# loss_weights:
# {'r': tensor(94.8829), 'a': 10, 'b': 10, 'e': tensor(0.0414)}
# loss_weights:
# {'r': tensor(93.2819), 'a': 10, 'b': 10, 'e': tensor(0.0413)}
# 7000	 4.2956E+00	 [3.1861339 5.012853  5.12651   5.386745  5.5978513]	 511.0204916000366
# loss_weights:
# {'r': tensor(93.5249), 'a': 10, 'b': 10, 'e': tensor(0.0412)}
# loss_weights:
# {'r': tensor(93.2277), 'a': 10, 'b': 10, 'e': tensor(0.0409)}
# loss_weights:
# {'r': tensor(91.8814), 'a': 10, 'b': 10, 'e': tensor(0.0407)}
# loss_weights:
# {'r': tensor(93.3644), 'a': 10, 'b': 10, 'e': tensor(0.0411)}
# loss_weights:
# {'r': tensor(92.9984), 'a': 10, 'b': 10, 'e': tensor(0.0411)}
# 7500	 4.0919E+00	 [3.051264  5.0514297 5.203189  5.4030757 5.6055055]	 547.6617639064789
# loss_weights:
# {'r': tensor(92.5726), 'a': 10, 'b': 10, 'e': tensor(0.0405)}
# loss_weights:
# {'r': tensor(93.6953), 'a': 10, 'b': 10, 'e': tensor(0.0403)}
# loss_weights:
# {'r': tensor(93.4687), 'a': 10, 'b': 10, 'e': tensor(0.0409)}
# loss_weights:
# {'r': tensor(93.4625), 'a': 10, 'b': 10, 'e': tensor(0.0407)}
# loss_weights:
# {'r': tensor(95.3205), 'a': 10, 'b': 10, 'e': tensor(0.0409)}
# 8000	 4.2981E+00	 [3.055359  5.147611  5.264953  5.514789  5.6570168]	 584.0841703414917
# loss_weights:
# {'r': tensor(92.4077), 'a': 10, 'b': 10, 'e': tensor(0.0407)}
# loss_weights:
# {'r': tensor(92.4350), 'a': 10, 'b': 10, 'e': tensor(0.0404)}
# loss_weights:
# {'r': tensor(92.4150), 'a': 10, 'b': 10, 'e': tensor(0.0404)}
# loss_weights:
# {'r': tensor(93.2257), 'a': 10, 'b': 10, 'e': tensor(0.0407)}
# loss_weights:
# {'r': tensor(93.8536), 'a': 10, 'b': 10, 'e': tensor(0.0408)}
# 8500	 4.1927E+00	 [2.9369419 5.106977  5.2798886 5.4939284 5.713758 ]	 620.4160943031311
# loss_weights:
# {'r': tensor(94.6742), 'a': 10, 'b': 10, 'e': tensor(0.0404)}
# loss_weights:
# {'r': tensor(93.4426), 'a': 10, 'b': 10, 'e': tensor(0.0402)}
# loss_weights:
# {'r': tensor(94.1022), 'a': 10, 'b': 10, 'e': tensor(0.0407)}
# loss_weights:
# {'r': tensor(92.4995), 'a': 10, 'b': 10, 'e': tensor(0.0400)}
# loss_weights:
# {'r': tensor(93.7340), 'a': 10, 'b': 10, 'e': tensor(0.0404)}
# 9000	 4.0623E+00	 [2.9403925 5.093722  5.3369236 5.5713987 5.752957 ]	 656.8200516700745
# loss_weights:
# {'r': tensor(95.2926), 'a': 10, 'b': 10, 'e': tensor(0.0406)}
# loss_weights:
# {'r': tensor(94.9647), 'a': 10, 'b': 10, 'e': tensor(0.0399)}
# loss_weights:
# {'r': tensor(93.8750), 'a': 10, 'b': 10, 'e': tensor(0.0406)}
# loss_weights:
# {'r': tensor(96.5988), 'a': 10, 'b': 10, 'e': tensor(0.0402)}
# loss_weights:
# {'r': tensor(95.9447), 'a': 10, 'b': 10, 'e': tensor(0.0403)}
# 9500	 4.1354E+00	 [2.827187  5.1474085 5.3867674 5.628336  5.859193 ]	 693.4968476295471
# loss_weights:
# {'r': tensor(96.6276), 'a': 10, 'b': 10, 'e': tensor(0.0401)}
# loss_weights:
# {'r': tensor(95.3866), 'a': 10, 'b': 10, 'e': tensor(0.0401)}
# loss_weights:
# {'r': tensor(96.7547), 'a': 10, 'b': 10, 'e': tensor(0.0404)}
# loss_weights:
# {'r': tensor(93.4981), 'a': 10, 'b': 10, 'e': tensor(0.0403)}
# loss_weights:
# {'r': tensor(94.8315), 'a': 10, 'b': 10, 'e': tensor(0.0399)}
# 10000	 4.1082E+00	 [2.7769494 5.2784224 5.3447027 5.687499  5.9272776]	 729.9957222938538
# loss_weights:
# {'r': tensor(96.6826), 'a': 10, 'b': 10, 'e': tensor(0.0401)}
# loss_weights:
# {'r': tensor(95.4781), 'a': 10, 'b': 10, 'e': tensor(0.0403)}
# loss_weights:
# {'r': tensor(96.8806), 'a': 10, 'b': 10, 'e': tensor(0.0402)}
# loss_weights:
# {'r': tensor(97.3906), 'a': 10, 'b': 10, 'e': tensor(0.0404)}
# loss_weights:
# {'r': tensor(97.4733), 'a': 10, 'b': 10, 'e': tensor(0.0406)}
# 10500	 4.2419E+00	 [2.6121454 5.278     5.348951  5.709208  5.9454894]	 766.5105922222137
# loss_weights:
# {'r': tensor(95.8860), 'a': 10, 'b': 10, 'e': tensor(0.0400)}
# loss_weights:
# {'r': tensor(95.9305), 'a': 10, 'b': 10, 'e': tensor(0.0403)}
# loss_weights:
# {'r': tensor(97.7510), 'a': 10, 'b': 10, 'e': tensor(0.0403)}
# loss_weights:
# {'r': tensor(99.0385), 'a': 10, 'b': 10, 'e': tensor(0.0402)}
# loss_weights:
# {'r': tensor(100.2943), 'a': 10, 'b': 10, 'e': tensor(0.0406)}
# 11000	 4.2181E+00	 [2.4563143 5.2376146 5.3799877 5.721053  5.9412656]	 803.4249300956726
# loss_weights:
# {'r': tensor(98.9168), 'a': 10, 'b': 10, 'e': tensor(0.0401)}
# loss_weights:
# {'r': tensor(101.1289), 'a': 10, 'b': 10, 'e': tensor(0.0403)}
# loss_weights:
# {'r': tensor(99.7956), 'a': 10, 'b': 10, 'e': tensor(0.0404)}
# loss_weights:
# {'r': tensor(101.4592), 'a': 10, 'b': 10, 'e': tensor(0.0406)}
# loss_weights:
# {'r': tensor(102.9240), 'a': 10, 'b': 10, 'e': tensor(0.0405)}
# 11500	 4.1184E+00	 [2.3363676 5.194134  5.303896  5.6983004 5.982435 ]	 840.2376959323883
# loss_weights:
# {'r': tensor(104.5925), 'a': 10, 'b': 10, 'e': tensor(0.0403)}
# loss_weights:
# {'r': tensor(99.7602), 'a': 10, 'b': 10, 'e': tensor(0.0405)}
# loss_weights:
# {'r': tensor(103.9222), 'a': 10, 'b': 10, 'e': tensor(0.0405)}
# loss_weights:
# {'r': tensor(103.6154), 'a': 10, 'b': 10, 'e': tensor(0.0402)}
# loss_weights:
# {'r': tensor(102.7702), 'a': 10, 'b': 10, 'e': tensor(0.0409)}
# 12000	 4.3639E+00	 [2.260547  5.2472744 5.3233376 5.8952975 6.2073345]	 876.7212011814117
# loss_weights:
# {'r': tensor(103.9015), 'a': 10, 'b': 10, 'e': tensor(0.0408)}
# loss_weights:
# {'r': tensor(105.0808), 'a': 10, 'b': 10, 'e': tensor(0.0409)}
# loss_weights:
# {'r': tensor(105.2559), 'a': 10, 'b': 10, 'e': tensor(0.0411)}
# loss_weights:
# {'r': tensor(105.9737), 'a': 10, 'b': 10, 'e': tensor(0.0404)}
# loss_weights:
# {'r': tensor(106.9257), 'a': 10, 'b': 10, 'e': tensor(0.0409)}
# 12500	 4.2878E+00	 [2.1055844 5.1802707 5.2565713 5.7039814 6.072305 ]	 913.1064829826355
# loss_weights:
# {'r': tensor(107.0207), 'a': 10, 'b': 10, 'e': tensor(0.0409)}
# loss_weights:
# {'r': tensor(107.7048), 'a': 10, 'b': 10, 'e': tensor(0.0412)}
# loss_weights:
# {'r': tensor(105.1266), 'a': 10, 'b': 10, 'e': tensor(0.0412)}
# loss_weights:
# {'r': tensor(107.1297), 'a': 10, 'b': 10, 'e': tensor(0.0412)}
# loss_weights:
# {'r': tensor(107.9709), 'a': 10, 'b': 10, 'e': tensor(0.0415)}
# 13000	 4.2579E+00	 [2.1176295 5.1024413 5.3216743 5.762365  5.969735 ]	 949.5775442123413
# loss_weights:
# {'r': tensor(109.0287), 'a': 10, 'b': 10, 'e': tensor(0.0414)}
# loss_weights:
# {'r': tensor(111.2243), 'a': 10, 'b': 10, 'e': tensor(0.0416)}
# loss_weights:
# {'r': tensor(113.2292), 'a': 10, 'b': 10, 'e': tensor(0.0418)}
# loss_weights:
# {'r': tensor(110.6074), 'a': 10, 'b': 10, 'e': tensor(0.0419)}
# loss_weights:
# {'r': tensor(111.8219), 'a': 10, 'b': 10, 'e': tensor(0.0424)}
# 13500	 4.3855E+00	 [2.1168802 4.877724  5.219828  5.700435  5.8707547]	 986.4008166790009
# loss_weights:
# {'r': tensor(112.7011), 'a': 10, 'b': 10, 'e': tensor(0.0420)}
# loss_weights:
# {'r': tensor(112.2753), 'a': 10, 'b': 10, 'e': tensor(0.0420)}
# loss_weights:
# {'r': tensor(113.1447), 'a': 10, 'b': 10, 'e': tensor(0.0426)}
# loss_weights:
# {'r': tensor(119.8510), 'a': 10, 'b': 10, 'e': tensor(0.0428)}
# loss_weights:
# {'r': tensor(116.3416), 'a': 10, 'b': 10, 'e': tensor(0.0428)}
# 14000	 4.3421E+00	 [2.0577548 4.613897  5.325128  5.616758  5.836848 ]	 1022.7023923397064
# loss_weights:
# {'r': tensor(121.1626), 'a': 10, 'b': 10, 'e': tensor(0.0431)}
# loss_weights:
# {'r': tensor(120.0308), 'a': 10, 'b': 10, 'e': tensor(0.0428)}
# loss_weights:
# {'r': tensor(122.9719), 'a': 10, 'b': 10, 'e': tensor(0.0436)}
# loss_weights:
# {'r': tensor(126.9637), 'a': 10, 'b': 10, 'e': tensor(0.0437)}
# loss_weights:
# {'r': tensor(121.1650), 'a': 10, 'b': 10, 'e': tensor(0.0445)}
# 14500	 4.1767E+00	 [2.0565455 4.266941  5.172719  5.4201    5.610747 ]	 1059.1115849018097
# loss_weights:
# {'r': tensor(128.2615), 'a': 10, 'b': 10, 'e': tensor(0.0450)}
# loss_weights:
# {'r': tensor(128.1980), 'a': 10, 'b': 10, 'e': tensor(0.0452)}
# loss_weights:
# {'r': tensor(130.2065), 'a': 10, 'b': 10, 'e': tensor(0.0457)}
# loss_weights:
# {'r': tensor(135.2528), 'a': 10, 'b': 10, 'e': tensor(0.0461)}
# loss_weights:
# {'r': tensor(138.4548), 'a': 10, 'b': 10, 'e': tensor(0.0464)}
# 15000	 4.3138E+00	 [2.0473309 3.5821445 4.945965  5.1677914 5.1859827]	 1095.8265602588654
# loss_weights:
# {'r': tensor(142.7962), 'a': 10, 'b': 10, 'e': tensor(0.0480)}
# loss_weights:
# {'r': tensor(140.2631), 'a': 10, 'b': 10, 'e': tensor(0.0485)}
# loss_weights:
# {'r': tensor(145.8818), 'a': 10, 'b': 10, 'e': tensor(0.0492)}
# loss_weights:
# {'r': tensor(148.7403), 'a': 10, 'b': 10, 'e': tensor(0.0494)}
# loss_weights:
# {'r': tensor(154.6942), 'a': 10, 'b': 10, 'e': tensor(0.0495)}
# 15500	 4.4478E+00	 [2.033945  3.3027892 4.5868363 4.796087  4.803145 ]	 1132.2110188007355
# loss_weights:
# {'r': tensor(164.5372), 'a': 10, 'b': 10, 'e': tensor(0.0510)}
# loss_weights:
# {'r': tensor(168.1200), 'a': 10, 'b': 10, 'e': tensor(0.0514)}
# loss_weights:
# {'r': tensor(169.4960), 'a': 10, 'b': 10, 'e': tensor(0.0527)}
# loss_weights:
# {'r': tensor(178.8786), 'a': 10, 'b': 10, 'e': tensor(0.0528)}
# loss_weights:
# {'r': tensor(191.7013), 'a': 10, 'b': 10, 'e': tensor(0.0541)}
# 16000	 4.5466E+00	 [1.9774116 3.2389228 3.9002275 4.4636326 4.651795 ]	 1168.504103899002
# loss_weights:
# {'r': tensor(198.3338), 'a': 10, 'b': 10, 'e': tensor(0.0541)}
# loss_weights:
# {'r': tensor(198.5711), 'a': 10, 'b': 10, 'e': tensor(0.0557)}
# loss_weights:
# {'r': tensor(214.3967), 'a': 10, 'b': 10, 'e': tensor(0.0567)}
# loss_weights:
# {'r': tensor(217.7751), 'a': 10, 'b': 10, 'e': tensor(0.0575)}
# loss_weights:
# {'r': tensor(226.3945), 'a': 10, 'b': 10, 'e': tensor(0.0574)}
# 16500	 4.4909E+00	 [1.9895204 3.1990707 3.5774782 3.9347236 4.510801 ]	 1205.1560015678406
# loss_weights:
# {'r': tensor(225.2565), 'a': 10, 'b': 10, 'e': tensor(0.0580)}
# loss_weights:
# {'r': tensor(244.5848), 'a': 10, 'b': 10, 'e': tensor(0.0590)}
# loss_weights:
# {'r': tensor(248.0062), 'a': 10, 'b': 10, 'e': tensor(0.0598)}
# loss_weights:
# {'r': tensor(257.1953), 'a': 10, 'b': 10, 'e': tensor(0.0605)}
# loss_weights:
# {'r': tensor(275.8540), 'a': 10, 'b': 10, 'e': tensor(0.0609)}
# 17000	 4.5161E+00	 [1.8660347 3.1027112 3.3188992 3.401762  4.429475 ]	 1241.570300102234
# loss_weights:
# {'r': tensor(285.9538), 'a': 10, 'b': 10, 'e': tensor(0.0616)}
# loss_weights:
# {'r': tensor(300.7660), 'a': 10, 'b': 10, 'e': tensor(0.0617)}
# loss_weights:
# {'r': tensor(327.5621), 'a': 10, 'b': 10, 'e': tensor(0.0630)}
# loss_weights:
# {'r': tensor(321.2708), 'a': 10, 'b': 10, 'e': tensor(0.0636)}
# loss_weights:
# {'r': tensor(350.6240), 'a': 10, 'b': 10, 'e': tensor(0.0643)}
# 17500	 5.7697E+00	 [1.8642808 3.0431716 3.1465173 3.226313  4.2228556]	 1277.8806462287903
# loss_weights:
# {'r': tensor(349.9957), 'a': 10, 'b': 10, 'e': tensor(0.0647)}
# loss_weights:
# {'r': tensor(378.6095), 'a': 10, 'b': 10, 'e': tensor(0.0655)}
# loss_weights:
# {'r': tensor(387.4273), 'a': 10, 'b': 10, 'e': tensor(0.0663)}
# loss_weights:
# {'r': tensor(390.6938), 'a': 10, 'b': 10, 'e': tensor(0.0664)}
# loss_weights:
# {'r': tensor(401.5272), 'a': 10, 'b': 10, 'e': tensor(0.0670)}
# 18000	 4.6145E+00	 [1.7371616 2.9517624 3.049909  3.0913754 4.114872 ]	 1314.3350384235382
# loss_weights:
# {'r': tensor(416.5183), 'a': 10, 'b': 10, 'e': tensor(0.0668)}
# loss_weights:
# {'r': tensor(447.0086), 'a': 10, 'b': 10, 'e': tensor(0.0677)}
# loss_weights:
# {'r': tensor(461.5073), 'a': 10, 'b': 10, 'e': tensor(0.0676)}
# loss_weights:
# {'r': tensor(473.0171), 'a': 10, 'b': 10, 'e': tensor(0.0683)}
# loss_weights:
# {'r': tensor(499.4864), 'a': 10, 'b': 10, 'e': tensor(0.0693)}
# 18500	 4.8507E+00	 [1.7064372 2.8753269 3.0007243 3.0034966 3.9661148]	 1350.9440257549286
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0694)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0703)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0699)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0704)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0706)}
# 19000	 3.6739E+00	 [1.6821016 2.7972574 2.81104   2.8643332 3.865756 ]	 1387.5219061374664
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0709)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0714)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0711)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0716)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0718)}
# 19500	 4.5439E+00	 [1.685254  2.7481425 2.7929099 2.8399842 3.8505843]	 1423.8542220592499
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0711)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0716)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0714)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0730)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0717)}
# 20000	 3.4507E+00	 [1.6314404 2.7283547 2.734998  2.7473798 3.884155 ]	 1460.6192526817322
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0733)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0722)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0730)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0739)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0737)}
# 20500	 3.0378E+00	 [1.6010172 2.7138252 2.7206182 2.7249475 3.8008418]	 1497.0341868400574
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0740)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0736)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0741)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0740)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0738)}
# 21000	 2.6436E+00	 [1.6085705 2.6659498 2.6739702 2.7084777 3.7616565]	 1533.5013318061829
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0739)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0745)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0737)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0745)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0735)}
# 21500	 3.7899E+00	 [1.6089696 2.6352787 2.6590595 2.65915   3.7819996]	 1570.2046582698822
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0737)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0756)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0750)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0746)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0751)}
# 22000	 2.8649E+00	 [1.5776616 2.6382694 2.6763422 2.6791599 3.7463322]	 1606.5725662708282
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0759)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0751)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0746)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0741)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0756)}
# 22500	 3.5874E+00	 [1.665772  2.606401  2.6371472 2.63741   3.7436244]	 1642.9213571548462
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0757)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0745)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0754)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0760)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0763)}
# 23000	 3.3962E+00	 [1.7064385 2.610648  2.6280046 2.634893  3.7206318]	 1679.479291677475
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0754)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0756)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0762)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0752)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0762)}
# 23500	 2.5852E+00	 [1.640471  2.6169302 2.6209242 2.6745815 3.716175 ]	 1716.038916349411
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0764)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0764)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0763)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0758)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0758)}
# 24000	 2.4289E+00	 [1.5717916 2.5941143 2.6139095 2.6162446 3.6856084]	 1752.3607513904572
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0765)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0760)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0768)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0762)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0739)}
# 24500	 1.9633E+00	 [1.5533581 2.5558949 2.5960095 2.5990763 3.7175577]	 1788.783457517624
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0761)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0759)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0759)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0766)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0768)}
# 25000	 3.1446E+00	 [1.6048288 2.5982406 2.608427  2.6398838 3.66658  ]	 1825.565884590149
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0765)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0753)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0767)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0768)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0756)}
# 25500	 2.1356E+00	 [1.5829536 2.6158786 2.620166  2.6387558 3.6797042]	 1862.0261533260345
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0753)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0756)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0759)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0756)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0766)}
# 26000	 2.9027E+00	 [1.5508301 2.5871568 2.5872977 2.6083505 3.668027 ]	 1898.390892982483
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0763)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0764)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0764)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0755)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0759)}
# 26500	 2.0077E+00	 [1.5787966 2.5595243 2.5715463 2.5936341 3.674912 ]	 1935.1550285816193
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0763)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0767)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0772)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0772)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0774)}
# 27000	 3.6471E+00	 [1.5825387 2.5814025 2.58309   2.587583  3.6875336]	 1971.615490436554
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0761)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0766)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0774)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0765)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0773)}
# 27500	 2.6199E+00	 [1.567225  2.5612917 2.5622485 2.5755243 3.609353 ]	 2008.0090551376343
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0774)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0771)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0774)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0770)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0773)}
# 28000	 2.8714E+00	 [1.6295269 2.568501  2.5774336 2.6069074 3.616029 ]	 2044.7675397396088
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0774)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0772)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0774)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0769)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0772)}
# 28500	 2.2489E+00	 [1.602442  2.5637305 2.6617017 2.7214959 3.675303 ]	 2081.326785326004
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0756)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0768)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0758)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0751)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0770)}
# 29000	 3.0839E+00	 [1.6646178 2.5906878 2.5955398 2.6584232 3.6543736]	 2117.8958852291107
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0769)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0773)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0772)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0777)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0773)}
# 29500	 2.0454E+00	 [1.5782663 2.547726  2.617577  2.619668  3.6353106]	 2154.3290145397186
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0763)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0775)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0768)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0775)}
# loss_weights:
# {'r': 500, 'a': 10, 'b': 10, 'e': tensor(0.0769)}

# %%
print(f"It takes {int(t//3600):}h {int(t/60 - 60 * int(t//3600)):}m {int(t - 60 * int(t/60 - 60 * int(t//3600)))}s")
# Out:
# It takes 0h 36m 30s

# %%
perceptron.save_model(params)

# %%
fig, ax = plt.subplots(1,1,figsize=(20,4))
ax.plot(a_list)
ax.set_xlim(0,params['I'])
ax.set_yscale('log')

# %%
fig, ax = plt.subplots(1,1,figsize=(20,4))
ax.plot(b_list)
ax.set_xlim(0,params['I'])
ax.set_yscale('log')

# %%
# loss
fig, ax = plt.subplots(1,1,figsize=(20,4))

ax.plot(l_list, linewidth=0.5, color='black', label='Total loss')
# ax.plot(np.array(l_list) - params['alpha']*np.array(a_list) - params['beta']*np.array(b_list), linewidth=0.5, color='green', label='1st term')
# ax.plot(a_list, linewidth=0.5, color='red', label='Normalisation')
# ax.plot(b_list, linewidth=0.5, color='blue', label='Orthogonalization')
# ax.axhline(y=10,linewidth=0.5, linestyle='--', color='grey')
# ax.plot(np.sum())
ax.legend()
ax.set_yscale('log')
ax.set_xlim(0,params['I'])
ax.set_ylabel('Loss')
ax.set_xlabel('Iteration number')
ax.set_ylim(0,1e2)
# Out:
# /tmp/ipykernel_11931/397181055.py:15: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax.set_ylim(0,1e2)
# (0.7029148959009996, 100.0)

# %%
fig, ax = plt.subplots(2,2,figsize=(16,10))

NUM_COLORS = params['M']

cm = plt.get_cmap('gist_rainbow')
# Loss

ax[0,1].set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])

ax[0,0].plot(l_list, linewidth=0.5, color='black', label='Total loss')
# ax[0,0].plot(np.array(l_list) - np.array(a_list) - 100*np.array(b_list), linewidth=0.5, color='green', label='1st term')
ax[0,0].plot(a_list, linewidth=0.5, color='red', label='Normalisation')
ax[0,0].plot(b_list, linewidth=0.5, color='blue', label='Orthogonalization')
ax[0,0].axhline(y=10,linewidth=0.5, linestyle='--', color='grey')
ax[0,0].legend()
ax[0,0].set_yscale('log')
ax[0,0].set_xlim(0,params['I'])
ax[0,0].set_ylabel('Loss')
ax[0,0].set_xlabel('Iteration number')


ax[1,0].set_prop_cycle(color=[cm(1.*i/NUM_COLORS) for i in range(NUM_COLORS)])
for m in range(perceptron.M):
  if np.array(e_list)[-2500:,m].std() < 0.25:
    alpha = 1
  else:
    alpha = 0.1
  ax[1,0].plot(np.array(e_list)[:,m],# color=colors[m], 
               linewidth=0.5, alpha=alpha)
ax[1,0].set_xlim(0,params['I'])
ax[1,0].set_ylim(0,7)
ax[1,0].set_yticks(np.arange(0,7+1,0.5))
ax[1,0].grid(axis='y')
ax[1,0].set_ylabel('Energy')
ax[1,0].set_xlabel('Iteration number')

for m in range(perceptron.M):
  if np.array(e_list)[-2500:,m].std() < 0.25:
    alpha = 0.75
  else:
    alpha = 0.1
  ax[0,1].plot(np.log10(abs(np.array(r_list)[:,m])),# color=colors[m], 
               linewidth=0.5, alpha=alpha)
ax[0,1].set_xlim(0,params['I'])
ax[0,1].grid(axis='y')
ax[0,1].set_ylabel(r'$\mathrm{log}_{10}|\mathrm{residual}|$')
ax[0,1].set_xlabel('Iteration number')
# ax[1,0].set_yscale('log')

# Table
vars=['H','D','M','B','L','mean','std',r'$\alpha$',r'$\beta$','I','optimizer',
      'lr','weight_decay',r'$\sigma$','time']
vals=[params['H'],perceptron.D,perceptron.M,params['B'],params['L'],0.0,r'$L/2$',params['alpha'],params['beta'],params['I'],'torch.optim.Adam',
      1e-3,1e-3,params['sigma'],f"{int(t//3600):}h {int(t/60 - 60 * int(t//3600)):}m {int(t - 60 * int(t/60 - 60 * int(t//3600)))}s"]
ax[1,1].set_axis_off()
ax[1,1].table(cellText = np.array([vars,vals]).transpose(),
              cellLoc ='center',  
              loc ='center')
ax[1,1].set_title('NN-based multistate solver parameters', fontweight ="bold", y=0.9)

print(np.sort(np.array(e_list)[-1,:]))

fig.savefig(f"../figs/D{params['D']}_M{params['M']}_H{params['H']}_L{params['L']}_rablim.png")
# Out:
# /tmp/ipykernel_11931/620506351.py:56: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ax[1,1].table(cellText = np.array([vars,vals]).transpose(),
# [1.5312501 2.565002  2.5853422 2.6711814 3.6218684]

# %%
np.sort(np.min(np.array(e_list)[-500:,:],axis=0))
# Out:
# array([1.5246173, 2.524334 , 2.529258 , 2.5325842, 3.578962 ],
#       dtype=float32)

# %%
perceptron.L
# Out:
# 4.499999999987134
